# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorDonadelli/PANDA/blob/master/aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introdução à biblioteca 'pandas'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/vccolombo/PANDA-aula2/master/data/train.csv"
df = pd.read_csv(url)

# %%
df.head() # Mostra os 5 primeiros elementos da tabela
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.tail() # Mostra os 5 ultimos elementos da tabela
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
df.head(15) # Mostra os 15 primeiros elementos da tabela
# Out:
#     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0             1         0       3  ...   7.2500   NaN         S
# 1             2         1       1  ...  71.2833   C85         C
# 2             3         1       3  ...   7.9250   NaN         S
# 3             4         1       1  ...  53.1000  C123         S
# 4             5         0       3  ...   8.0500   NaN         S
# 5             6         0       3  ...   8.4583   NaN         Q
# 6             7         0       1  ...  51.8625   E46         S
# 7             8         0       3  ...  21.0750   NaN         S
# 8             9         1       3  ...  11.1333   NaN         S
# 9            10         1       2  ...  30.0708   NaN         C
# 10           11         1       3  ...  16.7000    G6         S
# 11           12         1       1  ...  26.5500  C103         S
# 12           13         0       3  ...   8.0500   NaN         S
# 13           14         0       3  ...  31.2750   NaN         S
# 14           15         0       3  ...   7.8542   NaN         S
#
# [15 rows x 12 columns]

# %%
df.sample(5) # Mostra 5 elementos aleatórios
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 822          823         0       1  ...   0.0000   NaN         S
# 719          720         0       3  ...   7.7750   NaN         S
# 844          845         0       3  ...   8.6625   NaN         S
# 374          375         0       3  ...  21.0750   NaN         S
# 696          697         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df.Fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df_salvo = df

# %%
df["coluna 2"] = df["PassengerId"] * 2
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  coluna 2
# 0            1         0       3  ...   NaN        S         2
# 1            2         1       1  ...   C85        C         4
# 2            3         1       3  ...   NaN        S         6
# 3            4         1       1  ...  C123        S         8
# 4            5         0       3  ...   NaN        S        10
#
# [5 rows x 13 columns]

# %%
df.coluna3 = df["PassengerId"]
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
#    PassengerId  Survived  Pclass  ... Cabin Embarked  coluna 2
# 0            1         0       3  ...   NaN        S         2
# 1            2         1       1  ...   C85        C         4
# 2            3         1       3  ...   NaN        S         6
# 3            4         1       1  ...  C123        S         8
# 4            5         0       3  ...   NaN        S        10
#
# [5 rows x 13 columns]

# %%
df_salvo
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  coluna 2
# 0              1         0       3  ...   NaN        S         2
# 1              2         1       1  ...   C85        C         4
# 2              3         1       3  ...   NaN        S         6
# 3              4         1       1  ...  C123        S         8
# 4              5         0       3  ...   NaN        S        10
# ..           ...       ...     ...  ...   ...      ...       ...
# 886          887         0       2  ...   NaN        S      1774
# 887          888         1       1  ...   B42        S      1776
# 888          889         0       3  ...   NaN        S      1778
# 889          890         1       1  ...  C148        C      1780
# 890          891         0       3  ...   NaN        Q      1782
#
# [891 rows x 13 columns]

# %%
url = "https://raw.githubusercontent.com/vccolombo/PANDA-aula2/master/data/train.csv"
df = pd.read_csv(url)

# %%
df_copia = df.copy()

# %%
df['coluna nova'] = 1
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  coluna nova
# 0            1         0       3  ...   NaN        S            1
# 1            2         1       1  ...   C85        C            1
# 2            3         1       3  ...   NaN        S            1
# 3            4         1       1  ...  C123        S            1
# 4            5         0       3  ...   NaN        S            1
#
# [5 rows x 13 columns]

# %%
df_copia.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
# del df["coluna nova"]
df.drop(["coluna nova"], axis=1, inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.drop(["Cabin"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0            1         0       3  ...         A/5 21171   7.2500         S
# 1            2         1       1  ...          PC 17599  71.2833         C
# 2            3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1       1  ...            113803  53.1000         S
# 4            5         0       3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Embarked"] = df["Embarked"].fillna('S')

# %%
df["Embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
g = sns.catplot("Pclass", "Age", "Survived", data=df, kind="bar")
plt.show()

# %%
df_age_null = df[df["Age"].isnull() == True]
df_age_not_null = df[df["Age"].isnull() == False]

df_age_null.head()
# Out:
#     PassengerId  Survived  Pclass  ...  Ticket     Fare  Embarked
# 5             6         0       3  ...  330877   8.4583         Q
# 17           18         1       2  ...  244373  13.0000         S
# 19           20         1       3  ...    2649   7.2250         C
# 26           27         0       3  ...    2631   7.2250         C
# 28           29         1       3  ...  330959   7.8792         Q
#
# [5 rows x 11 columns]

# %%
df[df["Sex"] == "male"]
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 4              5         0       3  ...            373450   8.0500         S
# 5              6         0       3  ...            330877   8.4583         Q
# 6              7         0       1  ...             17463  51.8625         S
# 7              8         0       3  ...            349909  21.0750         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 883          884         0       2  ...  C.A./SOTON 34068  10.5000         S
# 884          885         0       3  ...   SOTON/OQ 392076   7.0500         S
# 886          887         0       2  ...            211536  13.0000         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [577 rows x 11 columns]

# %%
df_age_not_null_grouped = df_age_not_null.groupby(['Pclass', 'Sex'])
age_mean = df_age_not_null_grouped['Age'].mean().to_dict()
age_mean
# Out:
# {(1, 'female'): 34.61176470588235,
#  (1, 'male'): 41.28138613861386,
#  (2, 'female'): 28.722972972972972,
#  (2, 'male'): 30.74070707070707,
#  (3, 'female'): 21.75,
#  (3, 'male'): 26.507588932806325}

# %%
df_age_null.loc[::, 'Age'] = df_age_null.apply(lambda x: age_mean[(x['Pclass'], x['Sex'])], axis=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df_age_null.tail(5)
# Out:
#      PassengerId  Survived  Pclass  ...      Ticket     Fare  Embarked
# 859          860         0       3  ...        2629   7.2292         C
# 863          864         0       3  ...    CA. 2343  69.5500         S
# 868          869         0       3  ...      345777   9.5000         S
# 878          879         0       3  ...      349217   7.8958         S
# 888          889         0       3  ...  W./C. 6607  23.4500         S
#
# [5 rows x 11 columns]

# %%
df = pd.concat([df_age_null, df_age_not_null])
df.head()
# Out:
#     PassengerId  Survived  Pclass  ...  Ticket     Fare  Embarked
# 5             6         0       3  ...  330877   8.4583         Q
# 17           18         1       2  ...  244373  13.0000         S
# 19           20         1       3  ...    2649   7.2250         C
# 26           27         0       3  ...    2631   7.2250         C
# 28           29         1       3  ...  330959   7.8792         Q
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 5 to 890
# Data columns (total 11 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 83.5+ KB

# %%
df.drop(['Name', 'Ticket', 'PassengerId'], axis=1, inplace=True)
df.head()
# Out:
#     Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 5          0       3    male  26.507589      0      0   8.4583        Q
# 17         1       2    male  30.740707      0      0  13.0000        S
# 19         1       3  female  21.750000      0      0   7.2250        C
# 26         0       3    male  26.507589      0      0   7.2250        C
# 28         1       3  female  21.750000      0      0   7.8792        Q

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex'] = df['Sex'].apply(lambda x: 1 if x == 'male' else 0)
df.head()
# Out:
#     Survived  Pclass  Sex        Age  SibSp  Parch     Fare Embarked
# 5          0       3    1  26.507589      0      0   8.4583        Q
# 17         1       2    1  30.740707      0      0  13.0000        S
# 19         1       3    0  21.750000      0      0   7.2250        C
# 26         0       3    1  26.507589      0      0   7.2250        C
# 28         1       3    0  21.750000      0      0   7.8792        Q

# %%
le = LabelEncoder()
df['Embarked'] = le.fit_transform(df['Embarked'])

df.head()
# Out:
#     Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 5          0       3    1  26.507589      0      0   8.4583         1
# 17         1       2    1  30.740707      0      0  13.0000         2
# 19         1       3    0  21.750000      0      0   7.2250         0
# 26         0       3    1  26.507589      0      0   7.2250         0
# 28         1       3    0  21.750000      0      0   7.8792         1

# %% [markdown]
# Introdução à Arvore de Decisão

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
tree = DecisionTreeClassifier(random_state = 42)

# %%
X = df.drop(['Survived'], axis=1)
y = df['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=42, splitter='best')

# %%
accuracy_score(y_test, tree.predict(X_test))
# Out:
# 0.7982062780269058
